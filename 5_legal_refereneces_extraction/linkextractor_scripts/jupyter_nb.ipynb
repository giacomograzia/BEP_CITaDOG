# %%
import pandas as pd

# %%
df = pd.read_csv('test_output_with_legal_references.csv')

# %%
df
# Out:
#                         id  file_number  \
# 0   id_acm_energy_permit_0            1
# 1   id_acm_energy_permit_0            2
# 2   id_acm_energy_permit_1            1
# 3   id_acm_energy_permit_1            2
# 4  id_acm_energy_permit_10            1
#
#                                          text_pypdf2  \
# 0  ons kenmerk: acm/uit/606179 zaaknummer: acm/23...
# 1  ons kenmerk: acm/uit/606177 zaaknummer: acm/23...
# 2  ons kenmerk: acm/uit/617883 zaaknummer: acm/24...
# 3  ons kenmerk: acm/uit/617882 zaaknummer: acm/24...
# 4  ons kenmerk: acm/uit/618385 zaaknummer: acm/23...
#
#                                             headline  \
# 0  Intrekking op eigen verzoek leveringsvergunnin...
# 1  Intrekking op eigen verzoek leveringsvergunnin...
# 2  Intrekking leveringsvergunningen elektriciteit...
# 3  Intrekking leveringsvergunningen elektriciteit...
# 4  Vergunning elektriciteit Youfone Energie komt ...
#
# ...

# %%
print(df.legal_references[4])
# Out:
# {'ervan': {'category': 'uitspraak', 'attributes': {}}, 'artikel 95a, eerste lid, van de elektriciteitswet 1998': {'category': 'wet', 'attributes': {}}, 'artikel 95d, eerste lid, van de elektriciteitswet 1998': {'category': 'wet', 'attributes': {}}, 'hoofdstuk 8 van de elektriciteitswet 1998': {'category': 'wet', 'attributes': {}}, 'artikel 95e, eerste lid, van de elektriciteitswet 1998': {'category': 'wet', 'attributes': {}}, 'artikel 95d, eerste lid, van de elektriciteitswet': {'category': 'wet', 'attributes': {}}, 'elektriciteitswet 1998': {'category': 'wet', 'attributes': {}}, 'stcrt. 2013, nr. 9333': {'category': 'officiele-publicatie', 'attributes': {}}, 'stcrt. 2013, nr. 9697': {'category': 'officiele-publicatie', 'attributes': {}}, 'artikelen 3:40 en 3:41 van de algemene wet bestuursrecht': {'category': 'wet', 'attributes': {}}}

# %%
df = pd.read_csv('df_with_legal_references.csv')

# %%
df.sample(5)
# Out:
#                            id  file_number  \
# 337    id_acm_energy_permit_8            1
# 133  id_acm_energy_permit_219            1
# 279  id_acm_energy_permit_309            2
# 221  id_acm_energy_permit_273            1
# 240  id_acm_energy_permit_283            2
#
#                                            text_pypdf2  \
# 337  ons kenmerk: acm/uit/618188 zaaknummer: acm/24...
# 133  besluit nummer: 2013203380 betreft:zaak 13.016...
# 279  ons kenmerk: acm/uit/540105 zaaknummer: acm/20...
# 221  ons kenmerk: acm/uit/567829 zaaknummer: acm/21...
# 240  acm/uit/561623 zaaknummer: acm/21/052603 datum...
#
#                                               headline  \
# 337  Intrekking leveringsvergunning warmte door Cro...
# 133  Bergop Beheer B.V. mag elektriciteit leveren a...
# 279  Intrekking leveringsvergunning elektriciteit e...
# 221  Energiedirect en Vandebron Energie mogen bij e...
# 240  Intrekking leveringsvergunningen elektriciteit...
#
# ...

# %%
df_2= pd.read_csv('df_with_legal_references_3.csv')

# %%
df_2.to_csv('df_with_legal_references_3.csv', index=False)

# %%
df_2[df_2['legal_references'] != '{}']#.to_csv('df_with_legal_references_id11.csv', index=False)
# Out:
#                           id  file_number  \
# 0     id_acm_energy_permit_0            1
# 1     id_acm_energy_permit_0            2
# 2     id_acm_energy_permit_1            1
# 3     id_acm_energy_permit_1            2
# 4    id_acm_energy_permit_10            1
# ..                       ...          ...
# 354  id_acm_energy_permit_95            1
# 355  id_acm_energy_permit_96            1
# 356  id_acm_energy_permit_97            1
# 357  id_acm_energy_permit_98            1
# 358  id_acm_energy_permit_99            1
#
#                                            text_pypdf2  \
# 0    ons kenmerk: acm/uit/606179 zaaknummer: acm/23...
# 1    ons kenmerk: acm/uit/606177 zaaknummer: acm/23...
# 2    ons kenmerk: acm/uit/617883 zaaknummer: acm/24...
# 3    ons kenmerk: acm/uit/617882 zaaknummer: acm/24...
# 4    ons kenmerk: acm/uit/618385 zaaknummer: acm/23...
# ..                                                 ...
# 354  ons kenmerk: acm/uit/382061 zaaknummer: acm/17...
# ...

# %%
df_2= pd.read_csv('df_with_legal_references_id_11_lx.csv')

# %%
df_2.legal_references.iloc[0]
# Out:
# "{'orgen': {'category': 'uitspraak', 'attributes': {}}}"

# %%
import ast
df_no_ref= pd.read_csv('df_with_legal_references.csv')
df_no_ref.legal_references.apply(ast.literal_eval)
# Out:
# 0      {'besluit organisatie, mandaat, volmacht en ma...
# 1      {'artikel 95a, eerste lid, van de elektricitei...
# 2      {'vergu': {'category': 'uitspraak', 'attribute...
# 3      {'artikel 95d van de elektriciteitswet 1998': ...
# 4      {'ervan': {'category': 'uitspraak', 'attribute...
#                              ...
# 354                                                   {}
# 355                                                   {}
# 356                                                   {}
# 357                                                   {}
# 358                                                   {}
# Name: legal_references, Length: 359, dtype: object

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 24 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              359 non-null    object
#  1   file_number                                     359 non-null    int64
#  2   text_pypdf2                                     359 non-null    object
#  3   headline                                        359 non-null    object
#  4   description                                     359 non-null    object
#  5   publication_date                                359 non-null    object
#  6   decision_date                                   315 non-null    object
#  7   case                                            325 non-null    object
#  8   parties                                         238 non-null    object
# ...
